# %% [markdown]
# ### Configuración inicial

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from delta import configure_spark_with_delta_pip
import os

# Configuración del Master y Delta
master_url = "spark://spark-master:7077"

builder = SparkSession.builder \
    .appName("Ingesta_Bronze_SECOP") \
    .master(master_url) \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.sql.shuffle.partitions", "4") # Ajustado para entorno local

# Inicializar Spark con soporte para Delta Lake
spark = configure_spark_with_delta_pip(builder).getOrCreate()

print("SparkSession iniciada con éxito")
# Out:
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-9a589a87-1ee9-46e9-9e60-fbb68e1a2a7c;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 162ms :: artifacts dl 4ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.0.0 from central in [default]
# 	io.delta#delta-storage;3.0.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-9a589a87-1ee9-46e9-9e60-fbb68e1a2a7c
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/4ms)
# 26/01/28 02:40:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# SparkSession iniciada con éxito

# %% [markdown]
# ### Lectura del archivo CSV

# %%
csv_path = "/app/data/SECOP_II_Contratos_Electronicos_20260126.csv"

print("Leyendo CSV ..")

df_raw = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("multiLine", "true") \
    .option("escape", "\"") \
    .option("quote", "\"") \
    .load(csv_path)

print(f"Total de registros leídos: {df_raw.count()}")
df_raw.limit(5).toPandas()
# Out:
# Leyendo CSV ..
# 26/01/28 02:40:20 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# Total de registros leídos: 5276398
# 26/01/28 02:50:15 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#                            Nombre Entidad  Nit Entidad  \
# 0                                     JEP  901.140.004
# 1            ALCALDIA MUNICIPIO DE ARAUCA  800.102.504
# 2  RADIO TELEVISION NACIONAL DE COLOMBIA.  900.002.583
# 3               ALCALDIA DE GUAMAL - META  800.098.193
# 4        ALCALDIA MUNICIPAL DE VALLEDUPAR  800.098.911
#
#                  Departamento      Ciudad                    Localización  \
# 0  Distrito Capital de Bogotá      Bogotá       Colombia, Bogotá,  Bogotá
# 1                      Arauca      Arauca     Colombia,  Arauca ,  Arauca
# 2  Distrito Capital de Bogotá      Bogotá       Colombia, Bogotá,  Bogotá
# 3                        Meta      Guamal       Colombia,  Meta ,  Guamal
# 4                       Cesar  Valledupar  Colombia,  Cesar ,  Valledupar
#
#          Orden                                             Sector  \
# 0     Nacional                             No aplica/No pertenece
# 1  Territorial                                   Servicio Público
# 2     Nacional  Tecnologías de la Información y las Comunicaci...
# 3  Territorial                             No aplica/No pertenece
# 4  Territorial                                   Servicio Público
#
#                    Rama Entidad Centralizada Proceso de Compra  ...  \
# 0  Corporación Autónoma         Centralizada  CO1.BDOS.1108279  ...
# 1             Ejecutivo      Descentralizada  CO1.BDOS.3106524  ...
# 2             Ejecutivo         Centralizada  CO1.BDOS.4132503  ...
# 3  Corporación Autónoma         Centralizada  CO1.BDOS.7927329  ...
# 4             Ejecutivo         Centralizada  CO1.BDOS.2250151  ...
#
#   Tipo de documento Ordenador del gasto  \
# 0                           No definido
# 1                           No definido
# 2                           No definido
# 3                  Cédula de Ciudadanía
# 4                  Cédula de Ciudadanía
#
#   Número de documento Ordenador del gasto           Nombre supervisor  \
# 0                             No definido                 No definido
# 1                             No definido                 No definido
# 2                             No definido                 No definido
# 3                                86081881  GILMA CONSUELO ROBAYO MOYA
# 4                              1065578810   LUIS ENRIQUE GALVIS NUÑEZ
#
#   Tipo de documento supervisor Número de documento supervisor  \
# 0                  No definido                    No definido
# 1                  No definido                    No definido
# 2                  No definido                    No definido
# 3         Cédula de Ciudadanía                       51976005
# 4         Cédula de Ciudadanía                       77186812
#
#   Nombre Ordenador de Pago Tipo de documento Ordenador de Pago  \
# 0              No definido                         No definido
# 1              No definido                         No definido
# 2              No definido                         No definido
# 3              No definido                         No definido
# 4              No definido                         No definido
#
#   Número de documento Ordenador de Pago Documentos Tipo  \
# 0                           No definido              No
# 1                           No definido              No
# 2                           No definido              No
# 3                           No definido              No
# 4                           No definido              No
#
#   Descripcion Documentos Tipo
# 0                 No definido
# 1                 No definido
# 2                 No definido
# 3                 No definido
# 4                 No definido
#
# [5 rows x 87 columns]

# %% [markdown]
# ### Limpiar nombres de columnas

# %%
df_bronze = df_raw

for col_name in df_bronze.columns:
    clean_name = col_name.lower() \
        .replace(" ", "_") \
        .replace(".", "") \
        .replace("á", "a").replace("é", "e").replace("í", "i").replace("ó", "o").replace("ú", "u") \
        .replace("(", "").replace(")", "") \
        .replace(",", "").replace(";", "") # Añadimos estos para evitar el error de Delta
    
    df_bronze = df_bronze.withColumnRenamed(col_name, clean_name)

# 2. AGREGAR METADATA DE AUDITORÍA
df_bronze = df_bronze.withColumn(
    "_ingestion_time", 
    F.current_timestamp()
).withColumn(
    "_source_file", 
    F.input_file_name()
)

print("Columnas normalizadas y datos de auditoría agregados.")
print(f"Nuevas columnas: {df_bronze.columns[:5]}...") 
df_bronze.select("nombre_entidad", "_ingestion_time", "_source_file").show(5, False)
# Out:
# Columnas normalizadas y datos de auditoría agregados.
# Nuevas columnas: ['nombre_entidad', 'nit_entidad', 'departamento', 'ciudad', 'localizacion']...
# +--------------------------------------+--------------------------+-------------------------------------------------------------+
# |nombre_entidad                        |_ingestion_time           |_source_file                                                 |
# +--------------------------------------+--------------------------+-------------------------------------------------------------+
# |JEP                                   |2026-01-28 03:13:49.505482|file:///app/data/SECOP_II_Contratos_Electronicos_20260126.csv|
# |ALCALDIA MUNICIPIO DE ARAUCA          |2026-01-28 03:13:49.505482|file:///app/data/SECOP_II_Contratos_Electronicos_20260126.csv|
# |RADIO TELEVISION NACIONAL DE COLOMBIA.|2026-01-28 03:13:49.505482|file:///app/data/SECOP_II_Contratos_Electronicos_20260126.csv|
# |ALCALDIA DE GUAMAL - META             |2026-01-28 03:13:49.505482|file:///app/data/SECOP_II_Contratos_Electronicos_20260126.csv|
# |ALCALDIA MUNICIPAL DE VALLEDUPAR      |2026-01-28 03:13:49.505482|file:///app/data/SECOP_II_Contratos_Electronicos_20260126.csv|
# +--------------------------------------+--------------------------+-------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ### Guardar datos en Delta

# %%
# Usamos una ruta absoluta desde la raíz del contenedor
output_path = "/app/data/lakehouse/bronze/secop"

print(f"Guardando en capa Bronce en la ruta: {output_path}...")

# Ejecutamos la escritura
df_bronze.write.format("delta") \
    .mode("overwrite") \
    .save(output_path)

print(f" ¡Ingesta completada! Datos protegidos en Delta Lake.")
print(f" Total columnas en Bronce: {len(df_bronze.columns)}")
# Out:
# Guardando en capa Bronce en la ruta: /app/data/lakehouse/bronze/secop...
# [Stage 15:=====================================================>  (48 + 2) / 50]
#  ¡Ingesta completada! Datos protegidos en Delta Lake.
#  Total columnas en Bronce: 89

# %% [markdown]
# ### Leer Delta

# %%
bronze_path = "/app/data/lakehouse/bronze/secop"

# Leemos usando el formato "delta"
df_bronze_check = spark.read.format("delta").load(bronze_path)

print(f" Lectura exitosa. Registros en el Lakehouse: {df_bronze_check.count()}")
# Ver las primeras 5 filas con Pandas 
df_bronze_check.limit(5).toPandas()
# Out:
#  Lectura exitosa. Registros en el Lakehouse: 5276398
#                            nombre_entidad  nit_entidad  \
# 0                                     JEP  901.140.004
# 1            ALCALDIA MUNICIPIO DE ARAUCA  800.102.504
# 2  RADIO TELEVISION NACIONAL DE COLOMBIA.  900.002.583
# 3               ALCALDIA DE GUAMAL - META  800.098.193
# 4        ALCALDIA MUNICIPAL DE VALLEDUPAR  800.098.911
#
#                  departamento      ciudad                    localizacion  \
# 0  Distrito Capital de Bogotá      Bogotá       Colombia, Bogotá,  Bogotá
# 1                      Arauca      Arauca     Colombia,  Arauca ,  Arauca
# 2  Distrito Capital de Bogotá      Bogotá       Colombia, Bogotá,  Bogotá
# 3                        Meta      Guamal       Colombia,  Meta ,  Guamal
# 4                       Cesar  Valledupar  Colombia,  Cesar ,  Valledupar
#
#          orden                                             sector  \
# 0     Nacional                             No aplica/No pertenece
# 1  Territorial                                   Servicio Público
# 2     Nacional  Tecnologías de la Información y las Comunicaci...
# 3  Territorial                             No aplica/No pertenece
# 4  Territorial                                   Servicio Público
#
#                    rama entidad_centralizada proceso_de_compra  ...  \
# 0  Corporación Autónoma         Centralizada  CO1.BDOS.1108279  ...
# 1             Ejecutivo      Descentralizada  CO1.BDOS.3106524  ...
# 2             Ejecutivo         Centralizada  CO1.BDOS.4132503  ...
# 3  Corporación Autónoma         Centralizada  CO1.BDOS.7927329  ...
# 4             Ejecutivo         Centralizada  CO1.BDOS.2250151  ...
#
#             nombre_supervisor tipo_de_documento_supervisor  \
# 0                 No definido                  No definido
# 1                 No definido                  No definido
# 2                 No definido                  No definido
# 3  GILMA CONSUELO ROBAYO MOYA         Cédula de Ciudadanía
# 4   LUIS ENRIQUE GALVIS NUÑEZ         Cédula de Ciudadanía
#
#   numero_de_documento_supervisor nombre_ordenador_de_pago  \
# 0                    No definido              No definido
# 1                    No definido              No definido
# 2                    No definido              No definido
# 3                       51976005              No definido
# 4                       77186812              No definido
#
#   tipo_de_documento_ordenador_de_pago numero_de_documento_ordenador_de_pago  \
# 0                         No definido                           No definido
# 1                         No definido                           No definido
# 2                         No definido                           No definido
# 3                         No definido                           No definido
# 4                         No definido                           No definido
#
#   documentos_tipo descripcion_documentos_tipo            _ingestion_time  \
# 0              No                 No definido 2026-01-28 03:26:14.891016
# 1              No                 No definido 2026-01-28 03:26:14.891016
# 2              No                 No definido 2026-01-28 03:26:14.891016
# 3              No                 No definido 2026-01-28 03:26:14.891016
# 4              No                 No definido 2026-01-28 03:26:14.891016
#
#                                         _source_file
# 0  file:///app/data/SECOP_II_Contratos_Electronic...
# 1  file:///app/data/SECOP_II_Contratos_Electronic...
# 2  file:///app/data/SECOP_II_Contratos_Electronic...
# 3  file:///app/data/SECOP_II_Contratos_Electronic...
# 4  file:///app/data/SECOP_II_Contratos_Electronic...
#
# [5 rows x 89 columns]
